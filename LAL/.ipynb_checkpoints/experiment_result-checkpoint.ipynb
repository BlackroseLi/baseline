# %%
import os
os.chdir(r'D:\baseline\LAL')

from Classes.results import Results

filename = './exp/RotatedCheckerboard2x2.p'
res2plot = Results()
res2plot.readResult('RotatedCheckerboard2x2-exp')
res2plot.plotResults(metrics = ['accuracy'])
